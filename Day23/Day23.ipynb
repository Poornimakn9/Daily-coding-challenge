# %%
# Input data (single string)
data = "Ride101-Ramesh-Late Arrival-Bangalore, Ride102-Suresh-rude behavior-Hyderabad, Ride103-Mahesh-Late arrival-Bangalore"

# %%
# Task 1: Clean the Data
# Convert entire string to lowercase
clean_data = data.lower()
print("Clean Data:", clean_data)
# Out:
# Clean Data: ride101-ramesh-late arrival-bangalore, ride102-suresh-rude behavior-hyderabad, ride103-mahesh-late arrival-bangalore

# %%
# Task 2: Count Total Complaints
# Each record separated by comma
total_complaints = clean_data.count(",") + 1
print("Total Complaints:", total_complaints)
# Out:
# Total Complaints: 3

# %%
# Task 3: Count 'Late Arrival' Issues
late_arrival_count = clean_data.count("late arrival")
print("Late Arrival Issues:", late_arrival_count)
# Out:
# Late Arrival Issues: 2

# %%
# Task 4: Find Complaints from Bangalore
bangalore_count = clean_data.count("bangalore")
print("Bangalore Complaints:", bangalore_count)
# Out:
# Bangalore Complaints: 2

# %%
# Task 5: Extract First Driver Name
first_record = clean_data.split(",")[0]
driver_name = first_record.split("-")[1]
print("First Driver Name:", driver_name)
# Out:
# First Driver Name: ramesh

# %%
# Task 6: Replace Issue Names (Standardization)
standardized_data = clean_data.replace("rude behavior", "rude_behavior")
standardized_data = standardized_data.replace("late arrival", "late_arrival")

print("Standardized Data:", standardized_data)
# Out:
# Standardized Data: ride101-ramesh-late_arrival-bangalore, ride102-suresh-rude_behavior-hyderabad, ride103-mahesh-late_arrival-bangalore
